# %% [markdown]
# <a href="https://colab.research.google.com/github/bahing-rai/Introduction-to-AI/blob/main/OrdersDataFrameAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Product": ["Shirt", "Jeans", "Shoes", "Bag", "Cap"],
    "Price": [1200, 2200, 3500, 1800, 500],
    "Quantity_Sold": [50, 30, 20, 25, 60],
    "Quantity_Bought": [40, 25, 15, 20, 55]
}

df = pd.DataFrame(data)

# %%
df["Revenue"] = df["Price"] * df["Quantity_Sold"]
df["Profit"] = df["Revenue"] - (df["Price"] * df["Quantity_Bought"])

# %%
print("📊 Sales & Orders Data Overview:\n")
print(df)
# Out:
# 📊 Sales & Orders Data Overview:
#
#   Product  Price  Quantity_Sold  Quantity_Bought  Revenue  Profit
# 0   Shirt   1200             50               40    60000   12000
# 1   Jeans   2200             30               25    66000   11000
# 2   Shoes   3500             20               15    70000   17500
# 3     Bag   1800             25               20    45000    9000
# 4     Cap    500             60               55    30000    2500

# %%
print("\n🔎 Summary Statistics:\n")
print(df.describe())
# Out:
# 🔎 Summary Statistics:
#
#              Price  Quantity_Sold  Quantity_Bought       Revenue        Profit
# count     5.000000       5.000000         5.000000      5.000000      5.000000
# mean   1840.000000      37.000000        31.000000  54200.000000  10400.000000
# std    1128.273017      17.175564        16.355427  16528.762809   5424.481542
# min     500.000000      20.000000        15.000000  30000.000000   2500.000000
# 25%    1200.000000      25.000000        20.000000  45000.000000   9000.000000
# 50%    1800.000000      30.000000        25.000000  60000.000000  11000.000000
# 75%    2200.000000      50.000000        40.000000  66000.000000  12000.000000
# max    3500.000000      60.000000        55.000000  70000.000000  17500.000000

# %%
plt.figure(figsize=(8,5))
plt.bar(df["Product"], df["Revenue"], color="skyblue")
plt.title("Revenue by Product")
plt.xlabel("Products")
plt.ylabel("Revenue (NPR)")
plt.show()
